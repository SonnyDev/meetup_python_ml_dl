# %% [markdown]
# <a href="https://colab.research.google.com/github/SonnyDev/llm-apps-langchain/blob/main/Document_Loaders_et_Document_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. Chargement de la clé d'API

# %%
import os
import openai

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key = os.environ['OPENAI_API_KEY']

# %% [markdown]
# ### 2. Les chargeurs de documents

# %%
## TextLoader

# %%
from langchain.document_loaders import TextLoader

loader = TextLoader("./langchain.txt", encoding="utf-8")

docs = loader.load()

docs
# Out:
# [Document(page_content="1. Modules\n\n• Modèles : Les modèles sont des composants clés de LangChain qui permettent d'utiliser différents types de modèles de langage, tels que GPT-3, BERT, ou encore T5. Ces modèles peuvent être utilisés pour générer du texte, répondre à des questions, ou effectuer d'autres tâches liées au langage naturel.\n• Prompts : Les prompts sont des instructions ou des exemples donnés aux modèles de langage pour les guider dans leur génération de texte. Ils peuvent être utilisés pour spécifier le contexte, poser des questions ou fournir des indications supplémentaires.\n• Mémoire : La mémoire permet de stocker des informations entre les appels d'une chaîne ou d'un agent. Elle peut être utilisée pour conserver des états, des variables ou des résultats intermédiaires lors de l'exécution d'une séquence d'appels.\n• Indexes : Les indexes permettent de combiner des modèles de langage avec vos propres données textuelles. Ils facilitent la recherche et l'accès aux informations dans les données indexées.\n• Chaînes : Les chaînes sont des séquences d'appels à des modèles de langage ou à d'autres utilitaires. Elles permettent de créer des flux de travail complexes en enchaînant différentes étapes de traitement du langage naturel.\n• Agents : Les agents permettent d'utiliser des modèles de langage comme moteur de raisonnement en prenant des décisions et en effectuant des actions en fonction des instructions et des données d'entrée. Ils peuvent être utilisés pour créer des assistants virtuels ou des chatbots interactifs.\n\n2. Cas d'utilisation\n\n• Assistants personnels : Les applications d'assistants personnels utilisent LangChain pour prendre des actions, se souvenir des interactions et avoir des connaissances sur les données de l'utilisateur. Ils peuvent répondre aux questions, effectuer des tâches spécifiques et fournir des recommandations personnalisées.\n• Réponse aux questions : LangChain peut être utilisé pour répondre aux questions en utilisant des documents spécifiques. Il peut extraire les informations pertinentes des documents et générer des réponses précises.\n• Chatbots : Les chatbots utilisent LangChain pour interagir avec les utilisateurs en langage naturel. Ils peuvent comprendre les questions, fournir des réponses pertinentes et mener des conversations fluides.\n• Interrogation de données tabulaires : LangChain permet d'interroger des données stockées dans des formats tabulaires tels que des bases de données SQL ou des fichiers CSV. Il facilite l'extraction d'informations spécifiques et la manipulation des données tabulaires.\n• Interaction avec des API : LangChain peut être utilisé pour interagir avec des API externes. Il peut envoyer des requêtes, traiter les réponses et intégrer les résultats dans les applications basées sur LangChain.\n• Extraction : LangChain peut extraire des informations structurées à partir de textes non structurés. Il peut identifier des entités, des relations et des concepts clés dans le texte pour alimenter d'autres processus ou analyses.\n• Résumé : LangChain peut résumer des documents plus longs en générant des résumés concis et informatifs. Il peut extraire les points clés et les informations essentielles pour faciliter la compréhension et la prise de décision.\n• Évaluation : LangChain peut être utilisé pour évaluer des modèles génératifs en utilisant des modèles de langage. Il peut mesurer la qualité des réponses générées, la cohérence du langage et d'autres métriques d'évaluation.\n\n3. Sources de données\n\n• Bases de données SQL : LangChain permet d'interagir avec des bases de données SQL en utilisant le langage naturel. Il facilite la création de requêtes SQL, l'interrogation de bases de données SQL et l'interaction avec des bases de données SQL à l'aide d'agents.\n• Ensembles de données Power BI : LangChain offre des outils pour interagir avec des ensembles de données Power BI. Il permet de décrire des tables, d'exécuter des requêtes et d'ajouter des exemples s ...

# %%
len(docs)
# Out:
# 1

# %%
### CSVLoader

# %%
from langchain.document_loaders.csv_loader import CSVLoader
loader = CSVLoader(file_path='./titanic.csv')
data = loader.load()

# %%
data
# Out:
# [Document(page_content='PassengerId: 1\nSurvived: 0\nPclass: 3\nName: Braund, Mr. Owen Harris\nSex: male\nAge: 22\nSibSp: 1\nParch: 0\nTicket: A/5 21171\nFare: 7.25\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 0}),
#  Document(page_content='PassengerId: 2\nSurvived: 1\nPclass: 1\nName: Cumings, Mrs. John Bradley (Florence Briggs Thayer)\nSex: female\nAge: 38\nSibSp: 1\nParch: 0\nTicket: PC 17599\nFare: 71.2833\nCabin: C85\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 1}),
#  Document(page_content='PassengerId: 3\nSurvived: 1\nPclass: 3\nName: Heikkinen, Miss. Laina\nSex: female\nAge: 26\nSibSp: 0\nParch: 0\nTicket: STON/O2. 3101282\nFare: 7.925\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 2}),
#  Document(page_content='PassengerId: 4\nSurvived: 1\nPclass: 1\nName: Futrelle, Mrs. Jacques Heath (Lily May Peel)\nSex: female\nAge: 35\nSibSp: 1\nParch: 0\nTicket: 113803\nFare: 53.1\nCabin: C123\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 3}),
#  Document(page_content='PassengerId: 5\nSurvived: 0\nPclass: 3\nName: Allen, Mr. William Henry\nSex: male\nAge: 35\nSibSp: 0\nParch: 0\nTicket: 373450\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 4}),
#  Document(page_content='PassengerId: 6\nSurvived: 0\nPclass: 3\nName: Moran, Mr. James\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 330877\nFare: 8.4583\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 5}),
#  Document(page_content='PassengerId: 7\nSurvived: 0\nPclass: 1\nName: McCarthy, Mr. Timothy J\nSex: male\nAge: 54\nSibSp: 0\nParch: 0\nTicket: 17463\nFare: 51.8625\nCabin: E46\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 6}),
#  Document(page_content='PassengerId: 8\nSurvived: 0\nPclass: 3\nName: Palsson, Master. Gosta Leonard\nSex: male\nAge: 2\nSibSp: 3\nParch: 1\nTicket: 349909\nFare: 21.075\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 7}),
#  Document(page_content='PassengerId: 9\nSurvived: 1\nPclass: 3\nName: Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)\nSex: female\nAge: 27\nSibSp: 0\nParch: 2\nTicket: 347742\nFare: 11.1333\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 8}),
#  Document(page_content='PassengerId: 10\nSurvived: 1\nPclass: 2\nName: Nasser, Mrs. Nicholas (Adele Achem)\nSex: female\nAge: 14\nSibSp: 1\nParch: 0\nTicket: 237736\nFare: 30.0708\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 9}),
#  Document(page_content='PassengerId: 11\nSurvived: 1\nPclass: 3\nName: Sandstrom, Miss. Marguerite Rut\nSex: female\nAge: 4\nSibSp: 1\nParch: 1\nTicket: PP 9549\nFare: 16.7\nCabin: G6\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 10}),
#  Document(page_content='PassengerId: 12\nSurvived: 1\nPclass: 1\nName: Bonnell, Miss. Elizabeth\nSex: female\nAge: 58\nSibSp: 0\nParch: 0\nTicket: 113783\nFare: 26.55\nCabin: C103\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 11}),
#  Document(page_content='PassengerId: 13\nSurvived: 0\nPclass: 3\nName: Saundercock, Mr. William Henry\nSex: male\nAge: 20\nSibSp: 0\nParch: 0\nTicket: A/5. 2151\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 12}),
#  Document(page_content='PassengerId: 14\nSurvived: 0\nPclass: 3\nName: Andersson, Mr. Anders Johan\nSex: male\nAge: 39\nSibSp: 1\nParch: 5\nTicket: 347082\nFare: 31.275\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 13}),
#  Document(page_content='PassengerId: 15\nSurvived: 0\nPclass: 3\nName: Vestrom, Miss. Hulda Amanda Adolfina\nSex: female\nAge: 14\nSibSp: 0\nParch: 0\nTicket: 350406\nFare: 7.8542\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 14}),
#  Document(page_content='PassengerId: 16\nSurvived: 1\nPclass: 2\nName: Hewlett, Mrs. (Mary D Kingcome)\nSex: female\nAge: 55\nSibSp: 0\nParch: 0\nTicket: 248706\nFare: 16\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 15}),
#  Document(page_content='PassengerId: 17\nSurvived: 0\nPclass: 3\nName: Rice, Master. Eugene\nSex: male\nAge: 2\nSibSp: 4\nParch: 1\nTicket: 382652\nFare: 29.125\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 16}),
#  Document(page_content='PassengerId: 18\nSurvived: 1\nPclass: 2\nName: Williams, Mr. Charles Eugene\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 244373\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 17}),
#  Document(page_content='PassengerId: 19\nSurvived: 0\nPclass: 3\nName: Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)\nSex: female\nAge: 31\nSibSp: 1\nParch: 0\nTicket: 345763\nFare: 18\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 18}),
#  Document(page_content='PassengerId: 20\nSurvived: 1\nPclass: 3\nName: Masselmani, Mrs. Fatima\nSex: female\nAge: \nSibSp: 0\nParch: 0\nTicket: 2649\nFare: 7.225\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 19}),
#  Document(page_content='PassengerId: 21\nSurvived: 0\nPclass: 2\nName: Fynney, Mr. Joseph J\nSex: male\nAge: 35\nSibSp: 0\nParch: 0\nTicket: 239865\nFare: 26\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 20}),
#  Document(page_content='PassengerId: 22\nSurvived: 1\nPclass: 2\nName: Beesley, Mr. Lawrence\nSex: male\nAge: 34\nSibSp: 0\nParch: 0\nTicket: 248698\nFare: 13\nCabin: D56\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 21}),
#  Document(page_content='PassengerId: 23\nSurvived: 1\nPclass: 3\nName: McGowan, Miss. Anna "Annie"\nSex: female\nAge: 15\nSibSp: 0\nParch: 0\nTicket: 330923\nFare: 8.0292\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 22}),
#  Document(page_content='PassengerId: 24\nSurvived: 1\nPclass: 1\nName: Sloper, Mr. William Thompson\nSex: male\nAge: 28\nSibSp: 0\nParch: 0\nTicket: 113788\nFare: 35.5\nCabin: A6\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 23}),
#  Document(page_content='PassengerId: 25\nSurvived: 0\nPclass: 3\nName: Palsson, Miss. Torborg Danira\nSex: female\nAge: 8\nSibSp: 3\nParch: 1\nTicket: 349909\nFare: 21.075\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 24}),
#  Document(page_content='PassengerId: 26\nSurvived: 1\nPclass: 3\nName: Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)\nSex: female\nAge: 38\nSibSp: 1\nParch: 5\nTicket: 347077\nFare: 31.3875\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 25}),
#  Document(page_content='PassengerId: 27\nSurvived: 0\nPclass: 3\nName: Emir, Mr. Farred Chehab\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 2631\nFare: 7.225\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 26}),
#  Document(page_content='PassengerId: 28\nSurvived: 0\nPclass: 1\nName: Fortune, Mr. Charles Alexander\nSex: male\nAge: 19\nSibSp: 3\nParch: 2\nTicket: 19950\nFare: 263\nCabin: C23 C25 C27\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 27}),
#  Document(page_content='PassengerId: 29\nSurvived: 1\nPclass: 3\nName: O\'Dwyer, Miss. Ellen "Nellie"\nSex: female\nAge: \nSibSp: 0\nParch: 0\nTicket: 330959\nFare: 7.8792\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 28}),
#  Document(page_content='PassengerId: 30\nSurvived: 0\nPclass: 3\nName: Todoroff, Mr. Lalio\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 349216\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 29}),
#  Document(page_content='PassengerId: 31\nSurvived: 0\nPclass: 1\nName: Uruchurtu, Don. Manuel E\nSex: male\nAge: 40\nSibSp: 0\nParch: 0\nTicket: PC 17601\nFare: 27.7208\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 30}),
#  Document(page_content='PassengerId: 32\nSurvived: 1\nPclass: 1\nName: Spencer, Mrs. William Augustus (Marie Eugenie)\nSex: female\nAge: \nSibSp: 1\nParch: 0\nTicket: PC 17569\nFare: 146.5208\nCabin: B78\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 31}),
#  Document(page_content='PassengerId: 33\nSurvived: 1\nPclass: 3\nName: Glynn, Miss. Mary Agatha\nSex: female\nAge: \nSibSp: 0\nParch: 0\nTicket: 335677\nFare: 7.75\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 32}),
#  Document(page_content='PassengerId: 34\nSurvived: 0\nPclass: 2\nName: Wheadon, Mr. Edward H\nSex: male\nAge: 66\nSibSp: 0\nParch: 0\nTicket: C.A. 24579\nFare: 10.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 33}),
#  Document(page_content='PassengerId: 35\nSurvived: 0\nPclass: 1\nName: Meyer, Mr. Edgar Joseph\nSex: male\nAge: 28\nSibSp: 1\nParch: 0\nTicket: PC 17604\nFare: 82.1708\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 34}),
#  Document(page_content='PassengerId: 36\nSurvived: 0\nPclass: 1\nName: Holverson, Mr. Alexander Oskar\nSex: male\nAge: 42\nSibSp: 1\nParch: 0\nTicket: 113789\nFare: 52\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 35}),
#  Document(page_content='PassengerId: 37\nSurvived: 1\nPclass: 3\nName: Mamee, Mr. Hanna\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 2677\nFare: 7.2292\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 36}),
#  Document(page_content='PassengerId: 38\nSurvived: 0\nPclass: 3\nName: Cann, Mr. Ernest Charles\nSex: male\nAge: 21\nSibSp: 0\nParch: 0\nTicket: A./5. 2152\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 37}),
#  Document(page_content='PassengerId: 39\nSurvived: 0\nPclass: 3\nName: Vander Planke, Miss. Augusta Maria\nSex: female\nAge: 18\nSibSp: 2\nParch: 0\nTicket: 345764\nFare: 18\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 38}),
#  Document(page_content='PassengerId: 40\nSurvived: 1\nPclass: 3\nName: Nicola-Yarred, Miss. Jamila\nSex: female\nAge: 14\nSibSp: 1\nParch: 0\nTicket: 2651\nFare: 11.2417\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 39}),
#  Document(page_content='PassengerId: 41\nSurvived: 0\nPclass: 3\nName: Ahlin, Mrs. Johan (Johanna Persdotter Larsson)\nSex: female\nAge: 40\nSibSp: 1\nParch: 0\nTicket: 7546\nFare: 9.475\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 40}),
#  Document(page_content='PassengerId: 42\nSurvived: 0\nPclass: 2\nName: Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)\nSex: female\nAge: 27\nSibSp: 1\nParch: 0\nTicket: 11668\nFare: 21\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 41}),
#  Document(page_content='PassengerId: 43\nSurvived: 0\nPclass: 3\nName: Kraeff, Mr. Theodor\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 349253\nFare: 7.8958\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 42}),
#  Document(page_content='PassengerId: 44\nSurvived: 1\nPclass: 2\nName: Laroche, Miss. Simonne Marie Anne Andree\nSex: female\nAge: 3\nSibSp: 1\nParch: 2\nTicket: SC/Paris 2123\nFare: 41.5792\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 43}),
#  Document(page_content='PassengerId: 45\nSurvived: 1\nPclass: 3\nName: Devaney, Miss. Margaret Delia\nSex: female\nAge: 19\nSibSp: 0\nParch: 0\nTicket: 330958\nFare: 7.8792\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 44}),
#  Document(page_content='PassengerId: 46\nSurvived: 0\nPclass: 3\nName: Rogers, Mr. William John\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: S.C./A.4. 23567\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 45}),
#  Document(page_content='PassengerId: 47\nSurvived: 0\nPclass: 3\nName: Lennon, Mr. Denis\nSex: male\nAge: \nSibSp: 1\nParch: 0\nTicket: 370371\nFare: 15.5\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 46}),
#  Document(page_content="PassengerId: 48\nSurvived: 1\nPclass: 3\nName: O'Driscoll, Miss. Bridget\nSex: female\nAge: \nSibSp: 0\nParch: 0\nTicket: 14311\nFare: 7.75\nCabin: \nEmbarked: Q", metadata={'source': './titanic.csv', 'row': 47}),
#  Document(page_content='PassengerId: 49\nSurvived: 0\nPclass: 3\nName: Samaan, Mr. Youssef\nSex: male\nAge: \nSibSp: 2\nParch: 0\nTicket: 2662\nFare: 21.6792\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 48}),
#  Document(page_content='PassengerId: 50\nSurvived: 0\nPclass: 3\nName: Arnold-Franchi, Mrs. Josef (Josefine Franchi)\nSex: female\nAge: 18\nSibSp: 1\nParch: 0\nTicket: 349237\nFare: 17.8\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 49}),
#  Document(page_content='PassengerId: 51\nSurvived: 0\nPclass: 3\nName: Panula, Master. Juha Niilo\nSex: male\nAge: 7\nSibSp: 4\nParch: 1\nTicket: 3101295\nFare: 39.6875\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 50}),
#  Document(page_content='PassengerId: 52\nSurvived: 0\nPclass: 3\nName: Nosworthy, Mr. Richard Cater\nSex: male\nAge: 21\nSibSp: 0\nParch: 0\nTicket: A/4. 39886\nFare: 7.8\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 51}),
#  Document(page_content='PassengerId: 53\nSurvived: 1\nPclass: 1\nName: Harper, Mrs. Henry Sleeper (Myna Haxtun)\nSex: female\nAge: 49\nSibSp: 1\nParch: 0\nTicket: PC 17572\nFare: 76.7292\nCabin: D33\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 52}),
#  Document(page_content='PassengerId: 54\nSurvived: 1\nPclass: 2\nName: Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)\nSex: female\nAge: 29\nSibSp: 1\nParch: 0\nTicket: 2926\nFare: 26\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 53}),
#  Document(page_content='PassengerId: 55\nSurvived: 0\nPclass: 1\nName: Ostby, Mr. Engelhart Cornelius\nSex: male\nAge: 65\nSibSp: 0\nParch: 1\nTicket: 113509\nFare: 61.9792\nCabin: B30\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 54}),
#  Document(page_content='PassengerId: 56\nSurvived: 1\nPclass: 1\nName: Woolner, Mr. Hugh\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 19947\nFare: 35.5\nCabin: C52\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 55}),
#  Document(page_content='PassengerId: 57\nSurvived: 1\nPclass: 2\nName: Rugg, Miss. Emily\nSex: female\nAge: 21\nSibSp: 0\nParch: 0\nTicket: C.A. 31026\nFare: 10.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 56}),
#  Document(page_content='PassengerId: 58\nSurvived: 0\nPclass: 3\nName: Novel, Mr. Mansouer\nSex: male\nAge: 28.5\nSibSp: 0\nParch: 0\nTicket: 2697\nFare: 7.2292\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 57}),
#  Document(page_content='PassengerId: 59\nSurvived: 1\nPclass: 2\nName: West, Miss. Constance Mirium\nSex: female\nAge: 5\nSibSp: 1\nParch: 2\nTicket: C.A. 34651\nFare: 27.75\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 58}),
#  Document(page_content='PassengerId: 60\nSurvived: 0\nPclass: 3\nName: Goodwin, Master. William Frederick\nSex: male\nAge: 11\nSibSp: 5\nParch: 2\nTicket: CA 2144\nFare: 46.9\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 59}),
#  Document(page_content='PassengerId: 61\nSurvived: 0\nPclass: 3\nName: Sirayanian, Mr. Orsen\nSex: male\nAge: 22\nSibSp: 0\nParch: 0\nTicket: 2669\nFare: 7.2292\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 60}),
#  Document(page_content='PassengerId: 62\nSurvived: 1\nPclass: 1\nName: Icard, Miss. Amelie\nSex: female\nAge: 38\nSibSp: 0\nParch: 0\nTicket: 113572\nFare: 80\nCabin: B28\nEmbarked: ', metadata={'source': './titanic.csv', 'row': 61}),
#  Document(page_content='PassengerId: 63\nSurvived: 0\nPclass: 1\nName: Harris, Mr. Henry Birkhardt\nSex: male\nAge: 45\nSibSp: 1\nParch: 0\nTicket: 36973\nFare: 83.475\nCabin: C83\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 62}),
#  Document(page_content='PassengerId: 64\nSurvived: 0\nPclass: 3\nName: Skoog, Master. Harald\nSex: male\nAge: 4\nSibSp: 3\nParch: 2\nTicket: 347088\nFare: 27.9\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 63}),
#  Document(page_content='PassengerId: 65\nSurvived: 0\nPclass: 1\nName: Stewart, Mr. Albert A\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: PC 17605\nFare: 27.7208\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 64}),
#  Document(page_content='PassengerId: 66\nSurvived: 1\nPclass: 3\nName: Moubarek, Master. Gerios\nSex: male\nAge: \nSibSp: 1\nParch: 1\nTicket: 2661\nFare: 15.2458\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 65}),
#  Document(page_content='PassengerId: 67\nSurvived: 1\nPclass: 2\nName: Nye, Mrs. (Elizabeth Ramell)\nSex: female\nAge: 29\nSibSp: 0\nParch: 0\nTicket: C.A. 29395\nFare: 10.5\nCabin: F33\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 66}),
#  Document(page_content='PassengerId: 68\nSurvived: 0\nPclass: 3\nName: Crease, Mr. Ernest James\nSex: male\nAge: 19\nSibSp: 0\nParch: 0\nTicket: S.P. 3464\nFare: 8.1583\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 67}),
#  Document(page_content='PassengerId: 69\nSurvived: 1\nPclass: 3\nName: Andersson, Miss. Erna Alexandra\nSex: female\nAge: 17\nSibSp: 4\nParch: 2\nTicket: 3101281\nFare: 7.925\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 68}),
#  Document(page_content='PassengerId: 70\nSurvived: 0\nPclass: 3\nName: Kink, Mr. Vincenz\nSex: male\nAge: 26\nSibSp: 2\nParch: 0\nTicket: 315151\nFare: 8.6625\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 69}),
#  Document(page_content='PassengerId: 71\nSurvived: 0\nPclass: 2\nName: Jenkin, Mr. Stephen Curnow\nSex: male\nAge: 32\nSibSp: 0\nParch: 0\nTicket: C.A. 33111\nFare: 10.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 70}),
#  Document(page_content='PassengerId: 72\nSurvived: 0\nPclass: 3\nName: Goodwin, Miss. Lillian Amy\nSex: female\nAge: 16\nSibSp: 5\nParch: 2\nTicket: CA 2144\nFare: 46.9\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 71}),
#  Document(page_content='PassengerId: 73\nSurvived: 0\nPclass: 2\nName: Hood, Mr. Ambrose Jr\nSex: male\nAge: 21\nSibSp: 0\nParch: 0\nTicket: S.O.C. 14879\nFare: 73.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 72}),
#  Document(page_content='PassengerId: 74\nSurvived: 0\nPclass: 3\nName: Chronopoulos, Mr. Apostolos\nSex: male\nAge: 26\nSibSp: 1\nParch: 0\nTicket: 2680\nFare: 14.4542\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 73}),
#  Document(page_content='PassengerId: 75\nSurvived: 1\nPclass: 3\nName: Bing, Mr. Lee\nSex: male\nAge: 32\nSibSp: 0\nParch: 0\nTicket: 1601\nFare: 56.4958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 74}),
#  Document(page_content='PassengerId: 76\nSurvived: 0\nPclass: 3\nName: Moen, Mr. Sigurd Hansen\nSex: male\nAge: 25\nSibSp: 0\nParch: 0\nTicket: 348123\nFare: 7.65\nCabin: F G73\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 75}),
#  Document(page_content='PassengerId: 77\nSurvived: 0\nPclass: 3\nName: Staneff, Mr. Ivan\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 349208\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 76}),
#  Document(page_content='PassengerId: 78\nSurvived: 0\nPclass: 3\nName: Moutal, Mr. Rahamin Haim\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 374746\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 77}),
#  Document(page_content='PassengerId: 79\nSurvived: 1\nPclass: 2\nName: Caldwell, Master. Alden Gates\nSex: male\nAge: 0.83\nSibSp: 0\nParch: 2\nTicket: 248738\nFare: 29\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 78}),
#  Document(page_content='PassengerId: 80\nSurvived: 1\nPclass: 3\nName: Dowdell, Miss. Elizabeth\nSex: female\nAge: 30\nSibSp: 0\nParch: 0\nTicket: 364516\nFare: 12.475\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 79}),
#  Document(page_content='PassengerId: 81\nSurvived: 0\nPclass: 3\nName: Waelens, Mr. Achille\nSex: male\nAge: 22\nSibSp: 0\nParch: 0\nTicket: 345767\nFare: 9\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 80}),
#  Document(page_content='PassengerId: 82\nSurvived: 1\nPclass: 3\nName: Sheerlinck, Mr. Jan Baptist\nSex: male\nAge: 29\nSibSp: 0\nParch: 0\nTicket: 345779\nFare: 9.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 81}),
#  Document(page_content='PassengerId: 83\nSurvived: 1\nPclass: 3\nName: McDermott, Miss. Brigdet Delia\nSex: female\nAge: \nSibSp: 0\nParch: 0\nTicket: 330932\nFare: 7.7875\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 82}),
#  Document(page_content='PassengerId: 84\nSurvived: 0\nPclass: 1\nName: Carrau, Mr. Francisco M\nSex: male\nAge: 28\nSibSp: 0\nParch: 0\nTicket: 113059\nFare: 47.1\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 83}),
#  Document(page_content='PassengerId: 85\nSurvived: 1\nPclass: 2\nName: Ilett, Miss. Bertha\nSex: female\nAge: 17\nSibSp: 0\nParch: 0\nTicket: SO/C 14885\nFare: 10.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 84}),
#  Document(page_content='PassengerId: 86\nSurvived: 1\nPclass: 3\nName: Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)\nSex: female\nAge: 33\nSibSp: 3\nParch: 0\nTicket: 3101278\nFare: 15.85\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 85}),
#  Document(page_content='PassengerId: 87\nSurvived: 0\nPclass: 3\nName: Ford, Mr. William Neal\nSex: male\nAge: 16\nSibSp: 1\nParch: 3\nTicket: W./C. 6608\nFare: 34.375\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 86}),
#  Document(page_content='PassengerId: 88\nSurvived: 0\nPclass: 3\nName: Slocovski, Mr. Selman Francis\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: SOTON/OQ 392086\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 87}),
#  Document(page_content='PassengerId: 89\nSurvived: 1\nPclass: 1\nName: Fortune, Miss. Mabel Helen\nSex: female\nAge: 23\nSibSp: 3\nParch: 2\nTicket: 19950\nFare: 263\nCabin: C23 C25 C27\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 88}),
#  Document(page_content='PassengerId: 90\nSurvived: 0\nPclass: 3\nName: Celotti, Mr. Francesco\nSex: male\nAge: 24\nSibSp: 0\nParch: 0\nTicket: 343275\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 89}),
#  Document(page_content='PassengerId: 91\nSurvived: 0\nPclass: 3\nName: Christmann, Mr. Emil\nSex: male\nAge: 29\nSibSp: 0\nParch: 0\nTicket: 343276\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 90}),
#  Document(page_content='PassengerId: 92\nSurvived: 0\nPclass: 3\nName: Andreasson, Mr. Paul Edvin\nSex: male\nAge: 20\nSibSp: 0\nParch: 0\nTicket: 347466\nFare: 7.8542\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 91}),
#  Document(page_content='PassengerId: 93\nSurvived: 0\nPclass: 1\nName: Chaffee, Mr. Herbert Fuller\nSex: male\nAge: 46\nSibSp: 1\nParch: 0\nTicket: W.E.P. 5734\nFare: 61.175\nCabin: E31\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 92}),
#  Document(page_content='PassengerId: 94\nSurvived: 0\nPclass: 3\nName: Dean, Mr. Bertram Frank\nSex: male\nAge: 26\nSibSp: 1\nParch: 2\nTicket: C.A. 2315\nFare: 20.575\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 93}),
#  Document(page_content='PassengerId: 95\nSurvived: 0\nPclass: 3\nName: Coxon, Mr. Daniel\nSex: male\nAge: 59\nSibSp: 0\nParch: 0\nTicket: 364500\nFare: 7.25\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 94}),
#  Document(page_content='PassengerId: 96\nSurvived: 0\nPclass: 3\nName: Shorney, Mr. Charles Joseph\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 374910\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 95}),
#  Document(page_content='PassengerId: 97\nSurvived: 0\nPclass: 1\nName: Goldschmidt, Mr. George B\nSex: male\nAge: 71\nSibSp: 0\nParch: 0\nTicket: PC 17754\nFare: 34.6542\nCabin: A5\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 96}),
#  Document(page_content='PassengerId: 98\nSurvived: 1\nPclass: 1\nName: Greenfield, Mr. William Bertram\nSex: male\nAge: 23\nSibSp: 0\nParch: 1\nTicket: PC 17759\nFare: 63.3583\nCabin: D10 D12\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 97}),
#  Document(page_content='PassengerId: 99\nSurvived: 1\nPclass: 2\nName: Doling, Mrs. John T (Ada Julia Bone)\nSex: female\nAge: 34\nSibSp: 0\nParch: 1\nTicket: 231919\nFare: 23\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 98}),
#  Document(page_content='PassengerId: 100\nSurvived: 0\nPclass: 2\nName: Kantor, Mr. Sinai\nSex: male\nAge: 34\nSibSp: 1\nParch: 0\nTicket: 244367\nFare: 26\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 99}),
#  Document(page_content='PassengerId: 101\nSurvived: 0\nPclass: 3\nName: Petranec, Miss. Matilda\nSex: female\nAge: 28\nSibSp: 0\nParch: 0\nTicket: 349245\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 100}),
#  Document(page_content='PassengerId: 102\nSurvived: 0\nPclass: 3\nName: Petroff, Mr. Pastcho ("Pentcho")\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 349215\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 101}),
#  Document(page_content='PassengerId: 103\nSurvived: 0\nPclass: 1\nName: White, Mr. Richard Frasar\nSex: male\nAge: 21\nSibSp: 0\nParch: 1\nTicket: 35281\nFare: 77.2875\nCabin: D26\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 102}),
#  Document(page_content='PassengerId: 104\nSurvived: 0\nPclass: 3\nName: Johansson, Mr. Gustaf Joel\nSex: male\nAge: 33\nSibSp: 0\nParch: 0\nTicket: 7540\nFare: 8.6542\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 103}),
#  Document(page_content='PassengerId: 105\nSurvived: 0\nPclass: 3\nName: Gustafsson, Mr. Anders Vilhelm\nSex: male\nAge: 37\nSibSp: 2\nParch: 0\nTicket: 3101276\nFare: 7.925\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 104}),
#  Document(page_content='PassengerId: 106\nSurvived: 0\nPclass: 3\nName: Mionoff, Mr. Stoytcho\nSex: male\nAge: 28\nSibSp: 0\nParch: 0\nTicket: 349207\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 105}),
#  Document(page_content='PassengerId: 107\nSurvived: 1\nPclass: 3\nName: Salkjelsvik, Miss. Anna Kristine\nSex: female\nAge: 21\nSibSp: 0\nParch: 0\nTicket: 343120\nFare: 7.65\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 106}),
#  Document(page_content='PassengerId: 108\nSurvived: 1\nPclass: 3\nName: Moss, Mr. Albert Johan\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 312991\nFare: 7.775\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 107}),
#  Document(page_content='PassengerId: 109\nSurvived: 0\nPclass: 3\nName: Rekic, Mr. Tido\nSex: male\nAge: 38\nSibSp: 0\nParch: 0\nTicket: 349249\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 108}),
#  Document(page_content='PassengerId: 110\nSurvived: 1\nPclass: 3\nName: Moran, Miss. Bertha\nSex: female\nAge: \nSibSp: 1\nParch: 0\nTicket: 371110\nFare: 24.15\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 109}),
#  Document(page_content='PassengerId: 111\nSurvived: 0\nPclass: 1\nName: Porter, Mr. Walter Chamberlain\nSex: male\nAge: 47\nSibSp: 0\nParch: 0\nTicket: 110465\nFare: 52\nCabin: C110\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 110}),
#  Document(page_content='PassengerId: 112\nSurvived: 0\nPclass: 3\nName: Zabour, Miss. Hileni\nSex: female\nAge: 14.5\nSibSp: 1\nParch: 0\nTicket: 2665\nFare: 14.4542\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 111}),
#  Document(page_content='PassengerId: 113\nSurvived: 0\nPclass: 3\nName: Barton, Mr. David John\nSex: male\nAge: 22\nSibSp: 0\nParch: 0\nTicket: 324669\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 112}),
#  Document(page_content='PassengerId: 114\nSurvived: 0\nPclass: 3\nName: Jussila, Miss. Katriina\nSex: female\nAge: 20\nSibSp: 1\nParch: 0\nTicket: 4136\nFare: 9.825\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 113}),
#  Document(page_content='PassengerId: 115\nSurvived: 0\nPclass: 3\nName: Attalah, Miss. Malake\nSex: female\nAge: 17\nSibSp: 0\nParch: 0\nTicket: 2627\nFare: 14.4583\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 114}),
#  Document(page_content='PassengerId: 116\nSurvived: 0\nPclass: 3\nName: Pekoniemi, Mr. Edvard\nSex: male\nAge: 21\nSibSp: 0\nParch: 0\nTicket: STON/O 2. 3101294\nFare: 7.925\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 115}),
#  Document(page_content='PassengerId: 117\nSurvived: 0\nPclass: 3\nName: Connors, Mr. Patrick\nSex: male\nAge: 70.5\nSibSp: 0\nParch: 0\nTicket: 370369\nFare: 7.75\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 116}),
#  Document(page_content='PassengerId: 118\nSurvived: 0\nPclass: 2\nName: Turpin, Mr. William John Robert\nSex: male\nAge: 29\nSibSp: 1\nParch: 0\nTicket: 11668\nFare: 21\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 117}),
#  Document(page_content='PassengerId: 119\nSurvived: 0\nPclass: 1\nName: Baxter, Mr. Quigg Edmond\nSex: male\nAge: 24\nSibSp: 0\nParch: 1\nTicket: PC 17558\nFare: 247.5208\nCabin: B58 B60\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 118}),
#  Document(page_content='PassengerId: 120\nSurvived: 0\nPclass: 3\nName: Andersson, Miss. Ellis Anna Maria\nSex: female\nAge: 2\nSibSp: 4\nParch: 2\nTicket: 347082\nFare: 31.275\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 119}),
#  Document(page_content='PassengerId: 121\nSurvived: 0\nPclass: 2\nName: Hickman, Mr. Stanley George\nSex: male\nAge: 21\nSibSp: 2\nParch: 0\nTicket: S.O.C. 14879\nFare: 73.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 120}),
#  Document(page_content='PassengerId: 122\nSurvived: 0\nPclass: 3\nName: Moore, Mr. Leonard Charles\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: A4. 54510\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 121}),
#  Document(page_content='PassengerId: 123\nSurvived: 0\nPclass: 2\nName: Nasser, Mr. Nicholas\nSex: male\nAge: 32.5\nSibSp: 1\nParch: 0\nTicket: 237736\nFare: 30.0708\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 122}),
#  Document(page_content='PassengerId: 124\nSurvived: 1\nPclass: 2\nName: Webber, Miss. Susan\nSex: female\nAge: 32.5\nSibSp: 0\nParch: 0\nTicket: 27267\nFare: 13\nCabin: E101\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 123}),
#  Document(page_content='PassengerId: 125\nSurvived: 0\nPclass: 1\nName: White, Mr. Percival Wayland\nSex: male\nAge: 54\nSibSp: 0\nParch: 1\nTicket: 35281\nFare: 77.2875\nCabin: D26\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 124}),
#  Document(page_content='PassengerId: 126\nSurvived: 1\nPclass: 3\nName: Nicola-Yarred, Master. Elias\nSex: male\nAge: 12\nSibSp: 1\nParch: 0\nTicket: 2651\nFare: 11.2417\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 125}),
#  Document(page_content='PassengerId: 127\nSurvived: 0\nPclass: 3\nName: McMahon, Mr. Martin\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 370372\nFare: 7.75\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 126}),
#  Document(page_content='PassengerId: 128\nSurvived: 1\nPclass: 3\nName: Madsen, Mr. Fridtjof Arne\nSex: male\nAge: 24\nSibSp: 0\nParch: 0\nTicket: C 17369\nFare: 7.1417\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 127}),
#  Document(page_content='PassengerId: 129\nSurvived: 1\nPclass: 3\nName: Peter, Miss. Anna\nSex: female\nAge: \nSibSp: 1\nParch: 1\nTicket: 2668\nFare: 22.3583\nCabin: F E69\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 128}),
#  Document(page_content='PassengerId: 130\nSurvived: 0\nPclass: 3\nName: Ekstrom, Mr. Johan\nSex: male\nAge: 45\nSibSp: 0\nParch: 0\nTicket: 347061\nFare: 6.975\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 129}),
#  Document(page_content='PassengerId: 131\nSurvived: 0\nPclass: 3\nName: Drazenoic, Mr. Jozef\nSex: male\nAge: 33\nSibSp: 0\nParch: 0\nTicket: 349241\nFare: 7.8958\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 130}),
#  Document(page_content='PassengerId: 132\nSurvived: 0\nPclass: 3\nName: Coelho, Mr. Domingos Fernandeo\nSex: male\nAge: 20\nSibSp: 0\nParch: 0\nTicket: SOTON/O.Q. 3101307\nFare: 7.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 131}),
#  Document(page_content='PassengerId: 133\nSurvived: 0\nPclass: 3\nName: Robins, Mrs. Alexander A (Grace Charity Laury)\nSex: female\nAge: 47\nSibSp: 1\nParch: 0\nTicket: A/5. 3337\nFare: 14.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 132}),
#  Document(page_content='PassengerId: 134\nSurvived: 1\nPclass: 2\nName: Weisz, Mrs. Leopold (Mathilde Francoise Pede)\nSex: female\nAge: 29\nSibSp: 1\nParch: 0\nTicket: 228414\nFare: 26\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 133}),
#  Document(page_content='PassengerId: 135\nSurvived: 0\nPclass: 2\nName: Sobey, Mr. Samuel James Hayden\nSex: male\nAge: 25\nSibSp: 0\nParch: 0\nTicket: C.A. 29178\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 134}),
#  Document(page_content='PassengerId: 136\nSurvived: 0\nPclass: 2\nName: Richard, Mr. Emile\nSex: male\nAge: 23\nSibSp: 0\nParch: 0\nTicket: SC/PARIS 2133\nFare: 15.0458\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 135}),
#  Document(page_content='PassengerId: 137\nSurvived: 1\nPclass: 1\nName: Newsom, Miss. Helen Monypeny\nSex: female\nAge: 19\nSibSp: 0\nParch: 2\nTicket: 11752\nFare: 26.2833\nCabin: D47\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 136}),
#  Document(page_content='PassengerId: 138\nSurvived: 0\nPclass: 1\nName: Futrelle, Mr. Jacques Heath\nSex: male\nAge: 37\nSibSp: 1\nParch: 0\nTicket: 113803\nFare: 53.1\nCabin: C123\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 137}),
#  Document(page_content='PassengerId: 139\nSurvived: 0\nPclass: 3\nName: Osen, Mr. Olaf Elon\nSex: male\nAge: 16\nSibSp: 0\nParch: 0\nTicket: 7534\nFare: 9.2167\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 138}),
#  Document(page_content='PassengerId: 140\nSurvived: 0\nPclass: 1\nName: Giglio, Mr. Victor\nSex: male\nAge: 24\nSibSp: 0\nParch: 0\nTicket: PC 17593\nFare: 79.2\nCabin: B86\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 139}),
#  Document(page_content='PassengerId: 141\nSurvived: 0\nPclass: 3\nName: Boulos, Mrs. Joseph (Sultana)\nSex: female\nAge: \nSibSp: 0\nParch: 2\nTicket: 2678\nFare: 15.2458\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 140}),
#  Document(page_content='PassengerId: 142\nSurvived: 1\nPclass: 3\nName: Nysten, Miss. Anna Sofia\nSex: female\nAge: 22\nSibSp: 0\nParch: 0\nTicket: 347081\nFare: 7.75\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 141}),
#  Document(page_content='PassengerId: 143\nSurvived: 1\nPclass: 3\nName: Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)\nSex: female\nAge: 24\nSibSp: 1\nParch: 0\nTicket: STON/O2. 3101279\nFare: 15.85\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 142}),
#  Document(page_content='PassengerId: 144\nSurvived: 0\nPclass: 3\nName: Burke, Mr. Jeremiah\nSex: male\nAge: 19\nSibSp: 0\nParch: 0\nTicket: 365222\nFare: 6.75\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 143}),
#  Document(page_content='PassengerId: 145\nSurvived: 0\nPclass: 2\nName: Andrew, Mr. Edgardo Samuel\nSex: male\nAge: 18\nSibSp: 0\nParch: 0\nTicket: 231945\nFare: 11.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 144}),
#  Document(page_content='PassengerId: 146\nSurvived: 0\nPclass: 2\nName: Nicholls, Mr. Joseph Charles\nSex: male\nAge: 19\nSibSp: 1\nParch: 1\nTicket: C.A. 33112\nFare: 36.75\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 145}),
#  Document(page_content='PassengerId: 147\nSurvived: 1\nPclass: 3\nName: Andersson, Mr. August Edvard ("Wennerstrom")\nSex: male\nAge: 27\nSibSp: 0\nParch: 0\nTicket: 350043\nFare: 7.7958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 146}),
#  Document(page_content='PassengerId: 148\nSurvived: 0\nPclass: 3\nName: Ford, Miss. Robina Maggie "Ruby"\nSex: female\nAge: 9\nSibSp: 2\nParch: 2\nTicket: W./C. 6608\nFare: 34.375\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 147}),
#  Document(page_content='PassengerId: 149\nSurvived: 0\nPclass: 2\nName: Navratil, Mr. Michel ("Louis M Hoffman")\nSex: male\nAge: 36.5\nSibSp: 0\nParch: 2\nTicket: 230080\nFare: 26\nCabin: F2\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 148}),
#  Document(page_content='PassengerId: 150\nSurvived: 0\nPclass: 2\nName: Byles, Rev. Thomas Roussel Davids\nSex: male\nAge: 42\nSibSp: 0\nParch: 0\nTicket: 244310\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 149}),
#  Document(page_content='PassengerId: 151\nSurvived: 0\nPclass: 2\nName: Bateman, Rev. Robert James\nSex: male\nAge: 51\nSibSp: 0\nParch: 0\nTicket: S.O.P. 1166\nFare: 12.525\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 150}),
#  Document(page_content='PassengerId: 152\nSurvived: 1\nPclass: 1\nName: Pears, Mrs. Thomas (Edith Wearne)\nSex: female\nAge: 22\nSibSp: 1\nParch: 0\nTicket: 113776\nFare: 66.6\nCabin: C2\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 151}),
#  Document(page_content='PassengerId: 153\nSurvived: 0\nPclass: 3\nName: Meo, Mr. Alfonzo\nSex: male\nAge: 55.5\nSibSp: 0\nParch: 0\nTicket: A.5. 11206\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 152}),
#  Document(page_content='PassengerId: 154\nSurvived: 0\nPclass: 3\nName: van Billiard, Mr. Austin Blyler\nSex: male\nAge: 40.5\nSibSp: 0\nParch: 2\nTicket: A/5. 851\nFare: 14.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 153}),
#  Document(page_content='PassengerId: 155\nSurvived: 0\nPclass: 3\nName: Olsen, Mr. Ole Martin\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: Fa 265302\nFare: 7.3125\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 154}),
#  Document(page_content='PassengerId: 156\nSurvived: 0\nPclass: 1\nName: Williams, Mr. Charles Duane\nSex: male\nAge: 51\nSibSp: 0\nParch: 1\nTicket: PC 17597\nFare: 61.3792\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 155}),
#  Document(page_content='PassengerId: 157\nSurvived: 1\nPclass: 3\nName: Gilnagh, Miss. Katherine "Katie"\nSex: female\nAge: 16\nSibSp: 0\nParch: 0\nTicket: 35851\nFare: 7.7333\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 156}),
#  Document(page_content='PassengerId: 158\nSurvived: 0\nPclass: 3\nName: Corn, Mr. Harry\nSex: male\nAge: 30\nSibSp: 0\nParch: 0\nTicket: SOTON/OQ 392090\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 157}),
#  Document(page_content='PassengerId: 159\nSurvived: 0\nPclass: 3\nName: Smiljanic, Mr. Mile\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 315037\nFare: 8.6625\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 158}),
#  Document(page_content='PassengerId: 160\nSurvived: 0\nPclass: 3\nName: Sage, Master. Thomas Henry\nSex: male\nAge: \nSibSp: 8\nParch: 2\nTicket: CA. 2343\nFare: 69.55\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 159}),
#  Document(page_content='PassengerId: 161\nSurvived: 0\nPclass: 3\nName: Cribb, Mr. John Hatfield\nSex: male\nAge: 44\nSibSp: 0\nParch: 1\nTicket: 371362\nFare: 16.1\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 160}),
#  Document(page_content='PassengerId: 162\nSurvived: 1\nPclass: 2\nName: Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)\nSex: female\nAge: 40\nSibSp: 0\nParch: 0\nTicket: C.A. 33595\nFare: 15.75\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 161}),
#  Document(page_content='PassengerId: 163\nSurvived: 0\nPclass: 3\nName: Bengtsson, Mr. John Viktor\nSex: male\nAge: 26\nSibSp: 0\nParch: 0\nTicket: 347068\nFare: 7.775\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 162}),
#  Document(page_content='PassengerId: 164\nSurvived: 0\nPclass: 3\nName: Calic, Mr. Jovo\nSex: male\nAge: 17\nSibSp: 0\nParch: 0\nTicket: 315093\nFare: 8.6625\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 163}),
#  Document(page_content='PassengerId: 165\nSurvived: 0\nPclass: 3\nName: Panula, Master. Eino Viljami\nSex: male\nAge: 1\nSibSp: 4\nParch: 1\nTicket: 3101295\nFare: 39.6875\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 164}),
#  Document(page_content='PassengerId: 166\nSurvived: 1\nPclass: 3\nName: Goldsmith, Master. Frank John William "Frankie"\nSex: male\nAge: 9\nSibSp: 0\nParch: 2\nTicket: 363291\nFare: 20.525\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 165}),
#  Document(page_content='PassengerId: 167\nSurvived: 1\nPclass: 1\nName: Chibnall, Mrs. (Edith Martha Bowerman)\nSex: female\nAge: \nSibSp: 0\nParch: 1\nTicket: 113505\nFare: 55\nCabin: E33\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 166}),
#  Document(page_content='PassengerId: 168\nSurvived: 0\nPclass: 3\nName: Skoog, Mrs. William (Anna Bernhardina Karlsson)\nSex: female\nAge: 45\nSibSp: 1\nParch: 4\nTicket: 347088\nFare: 27.9\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 167}),
#  Document(page_content='PassengerId: 169\nSurvived: 0\nPclass: 1\nName: Baumann, Mr. John D\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: PC 17318\nFare: 25.925\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 168}),
#  Document(page_content='PassengerId: 170\nSurvived: 0\nPclass: 3\nName: Ling, Mr. Lee\nSex: male\nAge: 28\nSibSp: 0\nParch: 0\nTicket: 1601\nFare: 56.4958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 169}),
#  Document(page_content='PassengerId: 171\nSurvived: 0\nPclass: 1\nName: Van der hoef, Mr. Wyckoff\nSex: male\nAge: 61\nSibSp: 0\nParch: 0\nTicket: 111240\nFare: 33.5\nCabin: B19\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 170}),
#  Document(page_content='PassengerId: 172\nSurvived: 0\nPclass: 3\nName: Rice, Master. Arthur\nSex: male\nAge: 4\nSibSp: 4\nParch: 1\nTicket: 382652\nFare: 29.125\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 171}),
#  Document(page_content='PassengerId: 173\nSurvived: 1\nPclass: 3\nName: Johnson, Miss. Eleanor Ileen\nSex: female\nAge: 1\nSibSp: 1\nParch: 1\nTicket: 347742\nFare: 11.1333\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 172}),
#  Document(page_content='PassengerId: 174\nSurvived: 0\nPclass: 3\nName: Sivola, Mr. Antti Wilhelm\nSex: male\nAge: 21\nSibSp: 0\nParch: 0\nTicket: STON/O 2. 3101280\nFare: 7.925\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 173}),
#  Document(page_content='PassengerId: 175\nSurvived: 0\nPclass: 1\nName: Smith, Mr. James Clinch\nSex: male\nAge: 56\nSibSp: 0\nParch: 0\nTicket: 17764\nFare: 30.6958\nCabin: A7\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 174}),
#  Document(page_content='PassengerId: 176\nSurvived: 0\nPclass: 3\nName: Klasen, Mr. Klas Albin\nSex: male\nAge: 18\nSibSp: 1\nParch: 1\nTicket: 350404\nFare: 7.8542\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 175}),
#  Document(page_content='PassengerId: 177\nSurvived: 0\nPclass: 3\nName: Lefebre, Master. Henry Forbes\nSex: male\nAge: \nSibSp: 3\nParch: 1\nTicket: 4133\nFare: 25.4667\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 176}),
#  Document(page_content='PassengerId: 178\nSurvived: 0\nPclass: 1\nName: Isham, Miss. Ann Elizabeth\nSex: female\nAge: 50\nSibSp: 0\nParch: 0\nTicket: PC 17595\nFare: 28.7125\nCabin: C49\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 177}),
#  Document(page_content='PassengerId: 179\nSurvived: 0\nPclass: 2\nName: Hale, Mr. Reginald\nSex: male\nAge: 30\nSibSp: 0\nParch: 0\nTicket: 250653\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 178}),
#  Document(page_content='PassengerId: 180\nSurvived: 0\nPclass: 3\nName: Leonard, Mr. Lionel\nSex: male\nAge: 36\nSibSp: 0\nParch: 0\nTicket: LINE\nFare: 0\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 179}),
#  Document(page_content='PassengerId: 181\nSurvived: 0\nPclass: 3\nName: Sage, Miss. Constance Gladys\nSex: female\nAge: \nSibSp: 8\nParch: 2\nTicket: CA. 2343\nFare: 69.55\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 180}),
#  Document(page_content='PassengerId: 182\nSurvived: 0\nPclass: 2\nName: Pernot, Mr. Rene\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: SC/PARIS 2131\nFare: 15.05\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 181}),
#  Document(page_content='PassengerId: 183\nSurvived: 0\nPclass: 3\nName: Asplund, Master. Clarence Gustaf Hugo\nSex: male\nAge: 9\nSibSp: 4\nParch: 2\nTicket: 347077\nFare: 31.3875\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 182}),
#  Document(page_content='PassengerId: 184\nSurvived: 1\nPclass: 2\nName: Becker, Master. Richard F\nSex: male\nAge: 1\nSibSp: 2\nParch: 1\nTicket: 230136\nFare: 39\nCabin: F4\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 183}),
#  Document(page_content='PassengerId: 185\nSurvived: 1\nPclass: 3\nName: Kink-Heilmann, Miss. Luise Gretchen\nSex: female\nAge: 4\nSibSp: 0\nParch: 2\nTicket: 315153\nFare: 22.025\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 184}),
#  Document(page_content='PassengerId: 186\nSurvived: 0\nPclass: 1\nName: Rood, Mr. Hugh Roscoe\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 113767\nFare: 50\nCabin: A32\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 185}),
#  Document(page_content='PassengerId: 187\nSurvived: 1\nPclass: 3\nName: O\'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)\nSex: female\nAge: \nSibSp: 1\nParch: 0\nTicket: 370365\nFare: 15.5\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 186}),
#  Document(page_content='PassengerId: 188\nSurvived: 1\nPclass: 1\nName: Romaine, Mr. Charles Hallace ("Mr C Rolmane")\nSex: male\nAge: 45\nSibSp: 0\nParch: 0\nTicket: 111428\nFare: 26.55\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 187}),
#  Document(page_content='PassengerId: 189\nSurvived: 0\nPclass: 3\nName: Bourke, Mr. John\nSex: male\nAge: 40\nSibSp: 1\nParch: 1\nTicket: 364849\nFare: 15.5\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 188}),
#  Document(page_content='PassengerId: 190\nSurvived: 0\nPclass: 3\nName: Turcin, Mr. Stjepan\nSex: male\nAge: 36\nSibSp: 0\nParch: 0\nTicket: 349247\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 189}),
#  Document(page_content='PassengerId: 191\nSurvived: 1\nPclass: 2\nName: Pinsky, Mrs. (Rosa)\nSex: female\nAge: 32\nSibSp: 0\nParch: 0\nTicket: 234604\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 190}),
#  Document(page_content='PassengerId: 192\nSurvived: 0\nPclass: 2\nName: Carbines, Mr. William\nSex: male\nAge: 19\nSibSp: 0\nParch: 0\nTicket: 28424\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 191}),
#  Document(page_content='PassengerId: 193\nSurvived: 1\nPclass: 3\nName: Andersen-Jensen, Miss. Carla Christine Nielsine\nSex: female\nAge: 19\nSibSp: 1\nParch: 0\nTicket: 350046\nFare: 7.8542\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 192}),
#  Document(page_content='PassengerId: 194\nSurvived: 1\nPclass: 2\nName: Navratil, Master. Michel M\nSex: male\nAge: 3\nSibSp: 1\nParch: 1\nTicket: 230080\nFare: 26\nCabin: F2\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 193}),
#  Document(page_content='PassengerId: 195\nSurvived: 1\nPclass: 1\nName: Brown, Mrs. James Joseph (Margaret Tobin)\nSex: female\nAge: 44\nSibSp: 0\nParch: 0\nTicket: PC 17610\nFare: 27.7208\nCabin: B4\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 194}),
# ...
#  Document(page_content='PassengerId: 827\nSurvived: 0\nPclass: 3\nName: Lam, Mr. Len\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 1601\nFare: 56.4958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 826}),
#  Document(page_content='PassengerId: 828\nSurvived: 1\nPclass: 2\nName: Mallet, Master. Andre\nSex: male\nAge: 1\nSibSp: 0\nParch: 2\nTicket: S.C./PARIS 2079\nFare: 37.0042\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 827}),
#  Document(page_content='PassengerId: 829\nSurvived: 1\nPclass: 3\nName: McCormack, Mr. Thomas Joseph\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 367228\nFare: 7.75\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 828}),
#  Document(page_content='PassengerId: 830\nSurvived: 1\nPclass: 1\nName: Stone, Mrs. George Nelson (Martha Evelyn)\nSex: female\nAge: 62\nSibSp: 0\nParch: 0\nTicket: 113572\nFare: 80\nCabin: B28\nEmbarked: ', metadata={'source': './titanic.csv', 'row': 829}),
#  Document(page_content='PassengerId: 831\nSurvived: 1\nPclass: 3\nName: Yasbeck, Mrs. Antoni (Selini Alexander)\nSex: female\nAge: 15\nSibSp: 1\nParch: 0\nTicket: 2659\nFare: 14.4542\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 830}),
#  Document(page_content='PassengerId: 832\nSurvived: 1\nPclass: 2\nName: Richards, Master. George Sibley\nSex: male\nAge: 0.83\nSibSp: 1\nParch: 1\nTicket: 29106\nFare: 18.75\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 831}),
#  Document(page_content='PassengerId: 833\nSurvived: 0\nPclass: 3\nName: Saad, Mr. Amin\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 2671\nFare: 7.2292\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 832}),
#  Document(page_content='PassengerId: 834\nSurvived: 0\nPclass: 3\nName: Augustsson, Mr. Albert\nSex: male\nAge: 23\nSibSp: 0\nParch: 0\nTicket: 347468\nFare: 7.8542\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 833}),
#  Document(page_content='PassengerId: 835\nSurvived: 0\nPclass: 3\nName: Allum, Mr. Owen George\nSex: male\nAge: 18\nSibSp: 0\nParch: 0\nTicket: 2223\nFare: 8.3\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 834}),
#  Document(page_content='PassengerId: 836\nSurvived: 1\nPclass: 1\nName: Compton, Miss. Sara Rebecca\nSex: female\nAge: 39\nSibSp: 1\nParch: 1\nTicket: PC 17756\nFare: 83.1583\nCabin: E49\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 835}),
#  Document(page_content='PassengerId: 837\nSurvived: 0\nPclass: 3\nName: Pasic, Mr. Jakob\nSex: male\nAge: 21\nSibSp: 0\nParch: 0\nTicket: 315097\nFare: 8.6625\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 836}),
#  Document(page_content='PassengerId: 838\nSurvived: 0\nPclass: 3\nName: Sirota, Mr. Maurice\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 392092\nFare: 8.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 837}),
#  Document(page_content='PassengerId: 839\nSurvived: 1\nPclass: 3\nName: Chip, Mr. Chang\nSex: male\nAge: 32\nSibSp: 0\nParch: 0\nTicket: 1601\nFare: 56.4958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 838}),
#  Document(page_content='PassengerId: 840\nSurvived: 1\nPclass: 1\nName: Marechal, Mr. Pierre\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 11774\nFare: 29.7\nCabin: C47\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 839}),
#  Document(page_content='PassengerId: 841\nSurvived: 0\nPclass: 3\nName: Alhomaki, Mr. Ilmari Rudolf\nSex: male\nAge: 20\nSibSp: 0\nParch: 0\nTicket: SOTON/O2 3101287\nFare: 7.925\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 840}),
#  Document(page_content='PassengerId: 842\nSurvived: 0\nPclass: 2\nName: Mudd, Mr. Thomas Charles\nSex: male\nAge: 16\nSibSp: 0\nParch: 0\nTicket: S.O./P.P. 3\nFare: 10.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 841}),
#  Document(page_content='PassengerId: 843\nSurvived: 1\nPclass: 1\nName: Serepeca, Miss. Augusta\nSex: female\nAge: 30\nSibSp: 0\nParch: 0\nTicket: 113798\nFare: 31\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 842}),
#  Document(page_content='PassengerId: 844\nSurvived: 0\nPclass: 3\nName: Lemberopolous, Mr. Peter L\nSex: male\nAge: 34.5\nSibSp: 0\nParch: 0\nTicket: 2683\nFare: 6.4375\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 843}),
#  Document(page_content='PassengerId: 845\nSurvived: 0\nPclass: 3\nName: Culumovic, Mr. Jeso\nSex: male\nAge: 17\nSibSp: 0\nParch: 0\nTicket: 315090\nFare: 8.6625\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 844}),
#  Document(page_content='PassengerId: 846\nSurvived: 0\nPclass: 3\nName: Abbing, Mr. Anthony\nSex: male\nAge: 42\nSibSp: 0\nParch: 0\nTicket: C.A. 5547\nFare: 7.55\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 845}),
#  Document(page_content='PassengerId: 847\nSurvived: 0\nPclass: 3\nName: Sage, Mr. Douglas Bullen\nSex: male\nAge: \nSibSp: 8\nParch: 2\nTicket: CA. 2343\nFare: 69.55\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 846}),
#  Document(page_content='PassengerId: 848\nSurvived: 0\nPclass: 3\nName: Markoff, Mr. Marin\nSex: male\nAge: 35\nSibSp: 0\nParch: 0\nTicket: 349213\nFare: 7.8958\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 847}),
#  Document(page_content='PassengerId: 849\nSurvived: 0\nPclass: 2\nName: Harper, Rev. John\nSex: male\nAge: 28\nSibSp: 0\nParch: 1\nTicket: 248727\nFare: 33\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 848}),
#  Document(page_content='PassengerId: 850\nSurvived: 1\nPclass: 1\nName: Goldenberg, Mrs. Samuel L (Edwiga Grabowska)\nSex: female\nAge: \nSibSp: 1\nParch: 0\nTicket: 17453\nFare: 89.1042\nCabin: C92\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 849}),
#  Document(page_content='PassengerId: 851\nSurvived: 0\nPclass: 3\nName: Andersson, Master. Sigvard Harald Elias\nSex: male\nAge: 4\nSibSp: 4\nParch: 2\nTicket: 347082\nFare: 31.275\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 850}),
#  Document(page_content='PassengerId: 852\nSurvived: 0\nPclass: 3\nName: Svensson, Mr. Johan\nSex: male\nAge: 74\nSibSp: 0\nParch: 0\nTicket: 347060\nFare: 7.775\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 851}),
#  Document(page_content='PassengerId: 853\nSurvived: 0\nPclass: 3\nName: Boulos, Miss. Nourelain\nSex: female\nAge: 9\nSibSp: 1\nParch: 1\nTicket: 2678\nFare: 15.2458\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 852}),
#  Document(page_content='PassengerId: 854\nSurvived: 1\nPclass: 1\nName: Lines, Miss. Mary Conover\nSex: female\nAge: 16\nSibSp: 0\nParch: 1\nTicket: PC 17592\nFare: 39.4\nCabin: D28\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 853}),
#  Document(page_content='PassengerId: 855\nSurvived: 0\nPclass: 2\nName: Carter, Mrs. Ernest Courtenay (Lilian Hughes)\nSex: female\nAge: 44\nSibSp: 1\nParch: 0\nTicket: 244252\nFare: 26\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 854}),
#  Document(page_content='PassengerId: 856\nSurvived: 1\nPclass: 3\nName: Aks, Mrs. Sam (Leah Rosen)\nSex: female\nAge: 18\nSibSp: 0\nParch: 1\nTicket: 392091\nFare: 9.35\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 855}),
#  Document(page_content='PassengerId: 857\nSurvived: 1\nPclass: 1\nName: Wick, Mrs. George Dennick (Mary Hitchcock)\nSex: female\nAge: 45\nSibSp: 1\nParch: 1\nTicket: 36928\nFare: 164.8667\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 856}),
#  Document(page_content='PassengerId: 858\nSurvived: 1\nPclass: 1\nName: Daly, Mr. Peter Denis\nSex: male\nAge: 51\nSibSp: 0\nParch: 0\nTicket: 113055\nFare: 26.55\nCabin: E17\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 857}),
#  Document(page_content='PassengerId: 859\nSurvived: 1\nPclass: 3\nName: Baclini, Mrs. Solomon (Latifa Qurban)\nSex: female\nAge: 24\nSibSp: 0\nParch: 3\nTicket: 2666\nFare: 19.2583\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 858}),
#  Document(page_content='PassengerId: 860\nSurvived: 0\nPclass: 3\nName: Razi, Mr. Raihed\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 2629\nFare: 7.2292\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 859}),
#  Document(page_content='PassengerId: 861\nSurvived: 0\nPclass: 3\nName: Hansen, Mr. Claus Peter\nSex: male\nAge: 41\nSibSp: 2\nParch: 0\nTicket: 350026\nFare: 14.1083\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 860}),
#  Document(page_content='PassengerId: 862\nSurvived: 0\nPclass: 2\nName: Giles, Mr. Frederick Edward\nSex: male\nAge: 21\nSibSp: 1\nParch: 0\nTicket: 28134\nFare: 11.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 861}),
#  Document(page_content='PassengerId: 863\nSurvived: 1\nPclass: 1\nName: Swift, Mrs. Frederick Joel (Margaret Welles Barron)\nSex: female\nAge: 48\nSibSp: 0\nParch: 0\nTicket: 17466\nFare: 25.9292\nCabin: D17\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 862}),
#  Document(page_content='PassengerId: 864\nSurvived: 0\nPclass: 3\nName: Sage, Miss. Dorothy Edith "Dolly"\nSex: female\nAge: \nSibSp: 8\nParch: 2\nTicket: CA. 2343\nFare: 69.55\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 863}),
#  Document(page_content='PassengerId: 865\nSurvived: 0\nPclass: 2\nName: Gill, Mr. John William\nSex: male\nAge: 24\nSibSp: 0\nParch: 0\nTicket: 233866\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 864}),
#  Document(page_content='PassengerId: 866\nSurvived: 1\nPclass: 2\nName: Bystrom, Mrs. (Karolina)\nSex: female\nAge: 42\nSibSp: 0\nParch: 0\nTicket: 236852\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 865}),
#  Document(page_content='PassengerId: 867\nSurvived: 1\nPclass: 2\nName: Duran y More, Miss. Asuncion\nSex: female\nAge: 27\nSibSp: 1\nParch: 0\nTicket: SC/PARIS 2149\nFare: 13.8583\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 866}),
#  Document(page_content='PassengerId: 868\nSurvived: 0\nPclass: 1\nName: Roebling, Mr. Washington Augustus II\nSex: male\nAge: 31\nSibSp: 0\nParch: 0\nTicket: PC 17590\nFare: 50.4958\nCabin: A24\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 867}),
#  Document(page_content='PassengerId: 869\nSurvived: 0\nPclass: 3\nName: van Melkebeke, Mr. Philemon\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 345777\nFare: 9.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 868}),
#  Document(page_content='PassengerId: 870\nSurvived: 1\nPclass: 3\nName: Johnson, Master. Harold Theodor\nSex: male\nAge: 4\nSibSp: 1\nParch: 1\nTicket: 347742\nFare: 11.1333\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 869}),
#  Document(page_content='PassengerId: 871\nSurvived: 0\nPclass: 3\nName: Balkic, Mr. Cerin\nSex: male\nAge: 26\nSibSp: 0\nParch: 0\nTicket: 349248\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 870}),
#  Document(page_content='PassengerId: 872\nSurvived: 1\nPclass: 1\nName: Beckwith, Mrs. Richard Leonard (Sallie Monypeny)\nSex: female\nAge: 47\nSibSp: 1\nParch: 1\nTicket: 11751\nFare: 52.5542\nCabin: D35\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 871}),
#  Document(page_content='PassengerId: 873\nSurvived: 0\nPclass: 1\nName: Carlsson, Mr. Frans Olof\nSex: male\nAge: 33\nSibSp: 0\nParch: 0\nTicket: 695\nFare: 5\nCabin: B51 B53 B55\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 872}),
#  Document(page_content='PassengerId: 874\nSurvived: 0\nPclass: 3\nName: Vander Cruyssen, Mr. Victor\nSex: male\nAge: 47\nSibSp: 0\nParch: 0\nTicket: 345765\nFare: 9\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 873}),
#  Document(page_content='PassengerId: 875\nSurvived: 1\nPclass: 2\nName: Abelson, Mrs. Samuel (Hannah Wizosky)\nSex: female\nAge: 28\nSibSp: 1\nParch: 0\nTicket: P/PP 3381\nFare: 24\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 874}),
#  Document(page_content='PassengerId: 876\nSurvived: 1\nPclass: 3\nName: Najib, Miss. Adele Kiamie "Jane"\nSex: female\nAge: 15\nSibSp: 0\nParch: 0\nTicket: 2667\nFare: 7.225\nCabin: \nEmbarked: C', metadata={'source': './titanic.csv', 'row': 875}),
#  Document(page_content='PassengerId: 877\nSurvived: 0\nPclass: 3\nName: Gustafsson, Mr. Alfred Ossian\nSex: male\nAge: 20\nSibSp: 0\nParch: 0\nTicket: 7534\nFare: 9.8458\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 876}),
#  Document(page_content='PassengerId: 878\nSurvived: 0\nPclass: 3\nName: Petroff, Mr. Nedelio\nSex: male\nAge: 19\nSibSp: 0\nParch: 0\nTicket: 349212\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 877}),
#  Document(page_content='PassengerId: 879\nSurvived: 0\nPclass: 3\nName: Laleff, Mr. Kristo\nSex: male\nAge: \nSibSp: 0\nParch: 0\nTicket: 349217\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 878}),
#  Document(page_content='PassengerId: 880\nSurvived: 1\nPclass: 1\nName: Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)\nSex: female\nAge: 56\nSibSp: 0\nParch: 1\nTicket: 11767\nFare: 83.1583\nCabin: C50\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 879}),
#  Document(page_content='PassengerId: 881\nSurvived: 1\nPclass: 2\nName: Shelley, Mrs. William (Imanita Parrish Hall)\nSex: female\nAge: 25\nSibSp: 0\nParch: 1\nTicket: 230433\nFare: 26\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 880}),
#  Document(page_content='PassengerId: 882\nSurvived: 0\nPclass: 3\nName: Markun, Mr. Johann\nSex: male\nAge: 33\nSibSp: 0\nParch: 0\nTicket: 349257\nFare: 7.8958\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 881}),
#  Document(page_content='PassengerId: 883\nSurvived: 0\nPclass: 3\nName: Dahlberg, Miss. Gerda Ulrika\nSex: female\nAge: 22\nSibSp: 0\nParch: 0\nTicket: 7552\nFare: 10.5167\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 882}),
#  Document(page_content='PassengerId: 884\nSurvived: 0\nPclass: 2\nName: Banfield, Mr. Frederick James\nSex: male\nAge: 28\nSibSp: 0\nParch: 0\nTicket: C.A./SOTON 34068\nFare: 10.5\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 883}),
#  Document(page_content='PassengerId: 885\nSurvived: 0\nPclass: 3\nName: Sutehall, Mr. Henry Jr\nSex: male\nAge: 25\nSibSp: 0\nParch: 0\nTicket: SOTON/OQ 392076\nFare: 7.05\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 884}),
#  Document(page_content='PassengerId: 886\nSurvived: 0\nPclass: 3\nName: Rice, Mrs. William (Margaret Norton)\nSex: female\nAge: 39\nSibSp: 0\nParch: 5\nTicket: 382652\nFare: 29.125\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 885}),
#  Document(page_content='PassengerId: 887\nSurvived: 0\nPclass: 2\nName: Montvila, Rev. Juozas\nSex: male\nAge: 27\nSibSp: 0\nParch: 0\nTicket: 211536\nFare: 13\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 886}),
#  Document(page_content='PassengerId: 888\nSurvived: 1\nPclass: 1\nName: Graham, Miss. Margaret Edith\nSex: female\nAge: 19\nSibSp: 0\nParch: 0\nTicket: 112053\nFare: 30\nCabin: B42\nEmbarked: S', metadata={'source': './titanic.csv', 'row': 887}),
#  Document(page_content='PassengerId: 889\nSurvived: 0\nPclass: 3\nName: Johnston, Miss. Catherine Helen "Carrie"\nSex: female\nAge: \nSibSp: 1\nParch: 2\nTicket: W./C. 6607\nFare: 23.45\nCabin: \nEmbarked: S', metadata={'source': './titanic.csv', 'row': 888}),
#  Document(page_content='PassengerId: 890\nSurvived: 1\nPclass: 1\nName: Behr, Mr. Karl Howell\nSex: male\nAge: 26\nSibSp: 0\nParch: 0\nTicket: 111369\nFare: 30\nCabin: C148\nEmbarked: C', metadata={'source': './titanic.csv', 'row': 889}),
#  Document(page_content='PassengerId: 891\nSurvived: 0\nPclass: 3\nName: Dooley, Mr. Patrick\nSex: male\nAge: 32\nSibSp: 0\nParch: 0\nTicket: 370376\nFare: 7.75\nCabin: \nEmbarked: Q', metadata={'source': './titanic.csv', 'row': 890})]

# %%
len(data)
# Out:
# 891

# %%
### DirectoryLoader

# %%
# Ce chargeur nécessite le module unstructured
# !pip install unstructured

# %%
from langchain.document_loaders import DirectoryLoader

loader = DirectoryLoader("./document_loaders/files")
docs = loader.load()

# %%
docs[1]
# Out:
# Document(page_content="Les modèles sont des composants essentiels de LangChain qui permettent de réaliser des tâches de traitement du langage naturel. Ils sont conçus pour comprendre et générer du texte en fonction des instructions et des données d'entrée. Voici une explication détaillée sur les modèles dans LangChain :\n\nTypes de modèles :\n\nModèles de langage : Ces modèles sont formés pour prédire la probabilité d'une séquence de mots dans un langage donné. Ils sont utilisés pour générer du texte cohérent et fluide en fonction du contexte.\n\nModèles de traduction : Ces modèles sont spécifiquement conçus pour traduire du texte d'une langue source vers une langue cible. Ils utilisent des techniques de traduction automatique pour générer des traductions précises.\n\nModèles de question\n\nréponse : Ces modèles sont entraînés pour répondre à des questions spécifiques en utilisant des connaissances préalables ou des documents de référence. Ils extraient les informations pertinentes et génèrent des réponses précises aux questions posées.\n\nModèles de classification : Ces modèles sont utilisés pour classer des textes dans des catégories prédéfinies. Ils peuvent être utilisés pour la détection de spam, l'analyse des sentiments, la classification de documents, etc.\n\nFonctionnement des modèles :\n\nEntraînement : Les modèles de LangChain sont généralement pré\n\nentraînés sur de grandes quantités de données textuelles. Ils apprennent à capturer les structures et les relations du langage à partir de ces données d'entraînement.\n\nFine\n\ntuning : Après l'entraînement initial, les modèles peuvent être affinés ou adaptés à des tâches spécifiques en utilisant des données supplémentaires ou des techniques d'apprentissage par transfert. Cela permet d'améliorer les performances du modèle pour des tâches spécifiques.\n\nInférence : Une fois le modèle entraîné ou affiné, il peut être utilisé pour générer du texte, répondre à des questions, traduire des phrases, classer des documents, etc. L'inférence consiste à utiliser le modèle pour effectuer des prédictions sur de nouvelles données.\n\nUtilisation des modèles dans LangChain :\n\nIntégration : LangChain offre une interface conviviale pour intégrer différents types de modèles dans vos applications. Vous pouvez utiliser les modèles pré\n\nentraînés fournis par LangChain ou intégrer vos propres modèles personnalisés.\n\nPersonnalisation : LangChain permet de personnaliser les modèles en ajustant les paramètres, en ajoutant des prompts spécifiques ou en fine\n\ntunant les modèles sur des données supplémentaires. Cela permet d'adapter les modèles à des cas d'utilisation spécifiques.\n\nComposition : Les modèles peuvent être combinés en utilisant des chaînes ou des agents dans LangChain. Cela permet de créer des flux de travail complexes en enchaînant les appels à différents modèles ou en les combinant avec d'autres composants de LangChain.\n\nLes modèles dans LangChain sont des outils puissants pour le traitement du langage naturel. Ils permettent de générer du texte, de répondre à des questions, de traduire des phrases, de classer des documents, et bien plus encore. En comprenant le fonctionnement et l'utilisation des modèles, vous pouvez exploiter pleinement les capacités de LangChain pour développer des applications basées sur le langage.", metadata={'source': 'document_loaders\\files\\modèles.txt'})

# %%
### HTML
# BSHTMLLoader nécessite le module bs4
from langchain.document_loaders import BSHTMLLoader

loader = BSHTMLLoader("./document_loaders/index.html")

data = loader.load()

# %%
data
# Out:
# [Document(page_content='\n\nWIP-Privacy Policy\n\n\n\nWIP Privacy Policy\nThis Privacy Policy describes Our policies and procedures on the collection, use and disclosure of Your information when You use the Service and tells You about Your privacy rights and how the law protects You.\nWe use Your Personal data to provide and improve the Service. By using the Service, You agree to the collection and use of information in accordance with this Privacy Policy. This Privacy Policy has been created with the help of the Privacy Policy Generator.\nInterpretation and Definitions\nInterpretation\nThe words of which the initial letter is capitalized have meanings defined under the following conditions. The following definitions shall have the same meaning regardless of whether they appear in singular or in plural.\nDefinitions\nFor the purposes of this Privacy Policy:\n\n\nAccount means a unique account created for You to access our Service or parts of our Service.\n\n\nAffiliate means an entity that controls, is controlled by or is under common control with a party, where "control" means ownership of 50% or more of the shares, equity interest or other securities entitled to vote for election of directors or other managing authority.\n\n\nApplication means the software program provided by the Company downloaded by You on any electronic device, named WIP\n\n\nCompany (referred to as either "the Company", "We", "Us" or "Our" in this Agreement) refers to WIP.\n\n\nCountry refers to: France\n\n\nDevice means any device that can access the Service such as a computer, a cellphone or a digital tablet.\n\n\nPersonal Data is any information that relates to an identified or identifiable individual.\n\n\nService refers to the Application.\n\n\nService Provider means any natural or legal person who processes the data on behalf of the Company. It refers to third-party companies or individuals employed by the Company to facilitate the Service, to provide the Service on behalf of the Company, to perform services related to the Service or to assist the Company in analyzing how the Service is used.\n\n\nUsage Data refers to data collected automatically, either generated by the use of the Service or from the Service infrastructure itself (for example, the duration of a page visit).\n\n\nYou means the individual accessing or using the Service, or the company, or other legal entity on behalf of which such individual is accessing or using the Service, as applicable.\n\n\nCollecting and Using Your Personal Data\nTypes of Data Collected\nPersonal Data\nWhile using Our Service, We may ask You to provide Us with certain personally identifiable information that can be used to contact or identify You. Personally identifiable information may include, but is not limited to:\n\n\nEmail address\n\n\nFirst name and last name\n\n\nAddress, State, Province, ZIP/Postal code, City\n\n\nUsage Data\n\n\nUsage Data\nUsage Data is collected automatically when using the Service.\nUsage Data may include information such as Your Device’s Internet Protocol address (e.g. IP address), browser type, browser version, the pages of our Service that You visit, the time and date of Your visit, the time spent on those pages, unique device identifiers and other diagnostic data.\nWhen You access the Service by or through a mobile device, We may collect certain information automatically, including, but not limited to, the type of mobile device You use, Your mobile device unique ID, the IP address of Your mobile device, Your mobile operating system, the type of mobile Internet browser You use, unique device identifiers and other diagnostic data.\nWe may also collect information that Your browser sends whenever You visit our Service or when You access the Service by or through a mobile device.\nInformation Collected while Using the Application\nWhile using Our Application, in order to provide features of Our Application, We may collect, with Your prior permission:\n\nInformation regarding your  ...

# %%
### URLLoader (Unstructured)

from langchain.document_loaders import UnstructuredURLLoader

urls = [
    "https://www.lemondeinformatique.fr/actualites/lire-langchain-un-framework-qui-facilite-le-developpement-autour-des-llm-91921.html",
]

loader = UnstructuredURLLoader(urls=urls)

data = loader.load()

# %%
### URLLoader (Selenium : !pip install selenium) : supporte Javascript

from langchain.document_loaders import SeleniumURLLoader

urls = [
    "https://python.langchain.com/docs/modules/data_connection/document_loaders/",
    "https://python.langchain.com/docs/modules/data_connection/document_loaders/csv",
    "https://python.langchain.com/docs/modules/data_connection/document_loaders/file_directory",
    "https://python.langchain.com/docs/modules/data_connection/document_loaders/html",
    "https://python.langchain.com/docs/modules/data_connection/document_loaders/json",
    "https://python.langchain.com/docs/modules/data_connection/document_loaders/markdown",
    "https://python.langchain.com/docs/modules/data_connection/document_loaders/pdf"
]

loader = SeleniumURLLoader(urls=urls)

data = loader.load()

# %%
data[1]
# Out:
# Document(page_content='\n\nModules\n\nRetrieval\n\nDocument loaders\n\nCSV\n\nCSV\n\nA comma-separated values (CSV) file is a delimited text file that uses a comma to separate values. Each line of the file is a data record. Each record consists of one or more fields, separated by commas.\n\nLoad CSV data with a single row per document.\n\nfrom\n\nlangchain\n\ndocument_loaders\n\ncsv_loader\n\nimport\n\nCSVLoader\n\nloader\n\nCSVLoader\n\nfile_path\n\n\'./example_data/mlb_teams_2012.csv\'\n\ndata\n\nloader\n\nload\n\nprint\n\ndata\n\n[Document(page_content=\'Team: Nationals\\n"Payroll (millions)": 81.34\\n"Wins": 98\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 0}, lookup_index=0), Document(page_content=\'Team: Reds\\n"Payroll (millions)": 82.20\\n"Wins": 97\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 1}, lookup_index=0), Document(page_content=\'Team: Yankees\\n"Payroll (millions)": 197.96\\n"Wins": 95\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 2}, lookup_index=0), Document(page_content=\'Team: Giants\\n"Payroll (millions)": 117.62\\n"Wins": 94\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 3}, lookup_index=0), Document(page_content=\'Team: Braves\\n"Payroll (millions)": 83.31\\n"Wins": 94\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 4}, lookup_index=0), Document(page_content=\'Team: Athletics\\n"Payroll (millions)": 55.37\\n"Wins": 94\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 5}, lookup_index=0), Document(page_content=\'Team: Rangers\\n"Payroll (millions)": 120.51\\n"Wins": 93\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 6}, lookup_index=0), Document(page_content=\'Team: Orioles\\n"Payroll (millions)": 81.43\\n"Wins": 93\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 7}, lookup_index=0), Document(page_content=\'Team: Rays\\n"Payroll (millions)": 64.17\\n"Wins": 90\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 8}, lookup_index=0), Document(page_content=\'Team: Angels\\n"Payroll (millions)": 154.49\\n"Wins": 89\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 9}, lookup_index=0), Document(page_content=\'Team: Tigers\\n"Payroll (millions)": 132.30\\n"Wins": 88\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 10}, lookup_index=0), Document(page_content=\'Team: Cardinals\\n"Payroll (millions)": 110.30\\n"Wins": 88\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 11}, lookup_index=0), Document(page_content=\'Team: Dodgers\\n"Payroll (millions)": 95.14\\n"Wins": 86\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 12}, lookup_index=0), Document(page_content=\'Team: White Sox\\n"Payroll (millions)": 96.92\\n"Wins": 85\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 13}, lookup_index=0), Document(page_content=\'Team: Brewers\\n"Payroll (millions)": 97.65\\n"Wins": 83\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 14}, lookup_index=0), Document(page_content=\'Team: Phillies\\n"Payroll (millions)": 174.54\\n"Wins": 81\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 15}, lookup_index=0), Document(page_content=\'Team: Diamondbacks\\n"Payroll (millions)": 74.28\\n"Wins": 81\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 16}, lookup_index=0), Document(page_content=\'Team: Pirates\\n"Payroll (millions)": 63.43\\n"Wins": 79\', lookup_str=\'\', metadata={\'source\': \'./example_data/mlb_teams_2012.csv\', \'row\': 17}, lo ...

# %%
### PyPDFDirectoryLoader

from langchain.document_loaders import PyPDFDirectoryLoader

loader = PyPDFDirectoryLoader("document_loaders/pdfs/")

docs = loader.load()

# %%
len(docs)
# Out:
# 48

# %%
docs[0]
# Out:
# Document(page_content='A call to place g ender equality a t the heart of theGlobal Digit al Compact\nThechoicesthatwillbemadetodevelopsharedprinciplesforanopen,freeandsecuredigitalfutureforall-the“GlobalDigitalCompact”-willshapethedigitaltransformationofoursocietiesfortheyearstocome.Ifwefailatintersectingthedigitalevolutionandgenderequality,theworldwill miss out on the opportunity to build a better, safer and more equal future.\nInthepastyears,wehaveseenhowtechnologyoftenreinforcesaperniciouscycleinwhichexistinginequalitiesandstereotypesareamplifiedandperpetuated.Tobreakthiscycle,theActionCoalitiononTechnologyandInnovationforGenderEqualityisunitingpublic,civilsocietyandprivatepartnerstorevitalizetheglobalpartnershipfortheachievementofSDG51andsparkaworldleantowardsagender-diverse digital transformation.\nGenderequalityisnotanisolatedgoal:itiscriticaltosecuringasustainablefuturefortheplanet,addressingtherootcausesofpovertyandupholdinghumanrights,toleaveno-onebehind.OurcalltoadoptafeministapproachtotheGlobalDigitalCompactismuchmorethanconsideringwomenandgirlsinalltheirdiversity;rather,itisthemosteffectivepathtosecuringasustainabledigitalization and building a digital society which works for everyone.\nIfwearetomaximizetheimpactoftheprocessahead,webelievethedevelopmentoftheGlobalDigitalCompactshouldembracetheprinciplesandvaluesthathavemadethepreparationoftheBeijing Platform for Action and more recently Generation Equality a success:\nAninclusivedesign,whichfacilitatestheinclusionofdiversevoicesandstakeholders,inparticularthoseofyoungpeopleandthoseinmarginalizedpositionsorinsituationsofvulnerability,whosehuman rights might be threatened, and ensures accessibility for persons with disabilities.\nAnintersectionallens,whichtakesinconsiderationthemultidimensionalityofpeople’slivedexperiencesandrecognizestheprevalentpowerdynamicsandsystemsofinequalityanddiscrimination, and meaningfully and intentionally works to counter them.\nAnemphasisonFeministLeadership,whichacknowledgesthatwomenareoftenunder-representedindecision-makingprocesses,particularlyondigitalcooperation,andworksconsciouslytoredistribute power and responsibility to secure their equal participation.\nWehaveuntiltheendof2022toparticipateintheopenconsultativephaseoftheGlobalDigitalCompactandvoiceourinputs,individuallyandcollectively.BuildingontheGenerationEquality“GlobalAccelerationPlan”,theUNSecretary“OurCommonAgenda”andtheprinciplesthatwillguidethepreparationofthe67thsessionoftheCommissionontheStatusofWomen,2wesharebelowrecommendationsthatallowustoreimaginedigitalcooperationandcollectivelybuildthefuture specifically toward this change:\n2CSW 67 priority theme:“Inno vation and t echnologic alchange, and educ ation in the digit al age f or achie ving genderequality and the empo wermen t of all women and girls” .1Sustainable De velopmen t Goal 5: Achie ving g ender equality and empo wering all w omen and girls', metadata={'source': 'document_loaders\\pdfs\\220928_Action_Coalition_on_Innovation_and_Technology_for_Gender_Equality.pdf', 'page': 0})

# %% [markdown]
# ### 3. Transformation de documents

# %% [markdown]
# Les transformeurs de documents LangChain permettent d’adapter les données selon les besoins, comme diviser un long document en parties plus petites. Ces outils intégrés permettent facilement de scinder, combiner, filtrer et manipuler les documents.

# %%
### RecursiveCharacterSplit

# Load documents

from langchain.document_loaders import TextLoader

loader = TextLoader("./langchain.txt", encoding="utf-8")

docs = loader.load()

docs

# Transform documents

from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
    add_start_index=True,
)

texts = text_splitter.split_documents(docs)
texts[5]
# Out:
# Document(page_content='• Prompts : Les prompts sont des instructions ou des exemples donnés aux modèles de langage pour', metadata={'source': './langchain.txt', 'start_index': 314})

# %%
### Split by Token (!pip install tiktoken)

# Load documents
from langchain.document_loaders import DirectoryLoader

loader = DirectoryLoader("./document_loaders/files")
docs = loader.load()

# Split documents
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=500, chunk_overlap=0
)
texts = text_splitter.split_documents(docs)

print(len(docs))
print(len(texts))
print(texts[0])
print(len(texts[0].page_content))
# Out:
# 2
# 5
# page_content='Les chaînes (chains) sont un concept clé dans LangChain. Elles permettent de créer des flux de travail complexes en enchaînant les appels à des modèles de langage ou à d\'autres utilitaires. Voici une explication détaillée sur les chaînes dans LangChain :\n\nComposition des chaînes :\n\nLes chaînes sont composées de plusieurs étapes, appelées "runnables", qui peuvent être des modèles de langage, des utilitaires de traitement du texte ou d\'autres composants de LangChain.\n\nChaque runnable dans une chaîne reçoit une entrée et produit une sortie. La sortie d\'un runnable est transmise comme entrée au runnable suivant dans la chaîne.\n\nLes chaînes peuvent être linéaires, où les runnables sont exécutés séquentiellement, ou elles peuvent être plus complexes avec des branches et des fusions pour permettre des flux de travail parallèles ou conditionnels.\n\nUtilisation des chaînes :\n\nLes chaînes permettent de créer des pipelines de traitement du langage naturel en combinant différentes étapes de traitement.\n\nLes chaînes peuvent être utilisées pour effectuer des tâches telles que la génération de texte, la traduction, la classification, la recherche d\'informations, etc.\n\nLes chaînes peuvent être personnalisées en ajoutant des runnables supplémentaires ou en modifiant l\'ordre des runnables existants pour répondre aux besoins spécifiques d\'une application.\n\nAvantages des chaînes :' metadata={'source': 'document_loaders\\files\\Chaines.txt'}
# 1382

# %%
texts[4]
# Out:
# Document(page_content="Les modèles dans LangChain sont des outils puissants pour le traitement du langage naturel. Ils permettent de générer du texte, de répondre à des questions, de traduire des phrases, de classer des documents, et bien plus encore. En comprenant le fonctionnement et l'utilisation des modèles, vous pouvez exploiter pleinement les capacités de LangChain pour développer des applications basées sur le langage.", metadata={'source': 'document_loaders\\files\\modèles.txt'})
